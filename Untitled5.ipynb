# %% [markdown]
# <a href="https://colab.research.google.com/github/Daeun-Chi/Daeun-Chi.github.io/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#travel_insurance_3 파일 불러오기
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-f8c73de2-d945-4a88-802f-3300014aa05a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f8c73de2-d945-4a88-802f-3300014aa05a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np
import pandas as pd

# %%
pip install imbalanced-learn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# 타겟변수 및 X, y 지정
import pandas as pd
import io
filename = list(uploaded.keys())[0]
df = pd.read_csv(io.BytesIO(uploaded[filename]))
target_value_name = 'Claim'
X = df[df.columns.difference([target_value_name])]
y = df[target_value_name]

# %%
X
# Out:
#        Age Agency     AgencyType    Destination DistributionChannel  Duration  \
# 0       71    CBH  Travel Agency       MALAYSIA             Offline       186
# 1       32    CWT  Travel Agency      AUSTRALIA              Online        65
# 2       32    CWT  Travel Agency      AUSTRALIA              Online        60
# 3       41    CWT  Travel Agency          ITALY              Online        79
# 4       44    JZI       Airlines  UNITED STATES              Online        66
# ...    ...    ...            ...            ...                 ...       ...
# 60465   31    JZI       Airlines          JAPAN              Online       111
# 60466   40    JZI       Airlines          CHINA              Online        58
# 60467   57    JZI       Airlines       MALAYSIA              Online         2
# 60468   63    JZI       Airlines       VIET NAM              Online         3
# 60469   35    JZI       Airlines      HONG KONG              Online        22
#
# ...

# %%
y
# Out:
# 0        No
# 1        No
# 2        No
# 3        No
# 4        No
#          ..
# 60465    No
# 60466    No
# 60467    No
# 60468    No
# 60469    No
# Name: Claim, Length: 60470, dtype: object

# %%
# 언더샘플링 진행: y(claim yes/no)의 데이터 개수가 1:1이 되도록 랜덤으로 언더샘플링 (각 742개씩)
undersample = RandomUnderSampler(sampling_strategy='majority')
X_under, y_under = undersample.fit_resample(X, y)
print(Counter(y_under))
# Out:
# Counter({'No': 742, 'Yes': 742})

# %%
X_under
# Out:
#       Age Agency     AgencyType        Destination DistributionChannel  \
# 0      22    EPX  Travel Agency           MALAYSIA              Online
# 1      48    SSI       Airlines          SINGAPORE              Online
# 2      36    EPX  Travel Agency  BRUNEI DARUSSALAM              Online
# 3      57    JZI       Airlines          HONG KONG              Online
# 4      36    EPX  Travel Agency            MYANMAR              Online
# ...   ...    ...            ...                ...                 ...
# 1479   46    C2B       Airlines          SINGAPORE              Online
# 1480   35    EPX  Travel Agency           VIET NAM              Online
# 1481   30    C2B       Airlines          SINGAPORE              Online
# 1482   30    C2B       Airlines          SINGAPORE              Online
# 1483   28    C2B       Airlines          SINGAPORE              Online
#
#       Duration        ProductName
# 0           36  Cancellation Plan
# 1          152   Ticket Protector
# ...

# %%
y_under
# Out:
# 0        No
# 1        No
# 2        No
# 3        No
# 4        No
#        ...
# 1479    Yes
# 1480    Yes
# 1481    Yes
# 1482    Yes
# 1483    Yes
# Name: Claim, Length: 1484, dtype: object

# %%
# 두 데이터 합쳐서 csv 형식으로 바꾸기 (노션에서 너무 길어져서 상위 5개만 추출)
df1=pd.DataFrame(X_under)
df2=pd.DataFrame(y_under)
df3=pd.concat([df1,df2],axis=1)
df3_head = df3.head()
print(df3_head.to_csv(index=False))

# 원래 코드
# df1=pd.DataFrame(X_under)
# df2=pd.DataFrame(y_under)
# df3=pd.concat([df1,df2],axis=1)
# print(df3.to_csv(index=False))
# Out:
# Age,Agency,AgencyType,Destination,DistributionChannel,Duration,ProductName,Claim
# 22,EPX,Travel Agency,MALAYSIA,Online,36,Cancellation Plan,No
# 48,SSI,Airlines,SINGAPORE,Online,152,Ticket Protector,No
# 36,EPX,Travel Agency,BRUNEI DARUSSALAM,Online,5,Cancellation Plan,No
# 57,JZI,Airlines,HONG KONG,Online,159,Basic Plan,No
# 36,EPX,Travel Agency,MYANMAR,Online,19,Cancellation Plan,No
